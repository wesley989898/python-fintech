# %%
import requests
import json
from pandas.io.json import json_normalize
import pandas as pd

#fintech園區 api_token
news_api_token = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiIxOTYwIiwiaWF0IjoxNTUyMzY5MDQ5LCJpc3MiOiJ3cWpjZUNpTkdzdDNBMm80bTZURE81azhDalZxdTBnQiJ9.AoZV0GTHcefKg5Vgp4H2EJE_sjpEa3dG7nnjk3TWn_k'

news_api_url = 'https://api.fintechspace.com.tw/social/keywordSearch/news'
headers = {
    'Authorization':'Bearer '+news_api_token
}

#讀取上櫃公司excel檔
df = pd.read_excel('上櫃代號.xlsx', sheetname='Sheet1')

company_num = df['股票代號']
company_name = df['股票名稱']

count = 0 #計算跑到第幾筆

all_news = [] #all_news用來儲存最後merge完的資料

for i, v in zip(company_name, company_num): #個別搜尋公司新聞
    
    count += 1
    
    news_payload = {
    'keyword': '"' + str(i) + '"' + 'AND' + '"' +'('+str(v)+')' + '"',
    'type':'all',
    'start_date':'2019-04-09',
    'end_date':'2019-05-09',
    'limit':'1000',
    'apiToken':news_api_token
    }
    r = requests.get(news_api_url, headers=headers, params=news_payload)

    data = r.json()
    chart_data = data['result']
    news_list = []
    for v in chart_data:
        news_data = {
        'company': i,
        'sitename':v['sitename'],
        'type':v['type'],
        'title':v['title'],
        'url':v['url'],
        'time':v['time']
        }
        news_list.append(news_data) #儲存每家公司之新聞
    
    all_news += news_list #將每次各100則新聞merge，ex:兩家公司就是100+100、跑兩次。

dataset = pd.DataFrame(all_news)
dataset.to_excel('fintech資料0509.xlsx')


#如果資料量太大矩陣會裝不下，要分開來儲存    
'''
    #寫入excel中
    if count == 200:
        dataset = pd.DataFrame(all_news)
        dataset.to_excel('fintech資料0509_1.xlsx')
        all_news = []
        
    elif count == 431:
        dataset = pd.DataFrame(all_news)   
        dataset.to_excel('fintech資料0509_2.xlsx')
'''
# Out:
# C:\Users\wesley\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# C:\Users\wesley\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:832: UserWarning: Ignoring URL 'https://tw.stock.yahoo.com/news/%E6%AB%83%E8%B2%B7%E5%B8%82%E5%A0%B44-18%E6%9A%AB%E5%81%9C%E5%85%88%E8%B3%A3%E5%BE%8C%E8%B2%B7%E7%95%B6%E6%97%A5%E6%B2%96%E9%8A%B7%E6%A8%99%E5%80%9F%E5%8F%8A%E8%AD%B0%E5%80%9F%E6%A8%99%E7%9A%84%E5%90%8D%E5%96%AE-1-002342051.html' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ...

# %%
import pandas as pd

df = pd.read_excel('上櫃代號.xlsx', sheetname='Sheet1')

data_num = df['股票代號']
data_name = df['股票名稱']

for f, b in zip(data_num, data_name):
    print(f)
    print(b)
'''
for i in data_num:
    print(i)
'''
# Out:
# 4102
# 永日
# 4103
# 百略
# 4104
# 東貿
# 4105
# 東洋
# 4106
# 雃博
# 4107
# 邦拓
# 4108
# 懷特
# 4109
# 加捷
# 4110
# 博登
# 4111
# 濟生
# 4113
# 榮睿
# 4114
# 健喬
# 4205
# 恆義
# 4207
# 環泰
# 4303
# 信立
# 4304
# 琨詰
# 4305
# 世坤
# 4306
# 炎洲
# 4401
# 東隆興
# 4402
# 福大
# 4404
# 百成行
# 4406
# 新昕
# 4408
# 聯明
# 4413
# 赤崁
# 4414
# 如興
# 4415
# 勤龍
# 4416
# 福纖實業
# 4417
# 金洲
# 4419
# 松懋化學
# 4420
# 光明
# 6502
# 國隆
# 4502
# 源恆
# 4503
# 金雨
# 4506
# 崇友
# 4510
# 高鋒
# 4513
# 福裕
# 4522
# 大寶
# 4523
# 永彰
# 4526
# 東台
# 4527
# 方土霖
# 4528
# 江興鍛壓
# 4529
# 力武
# 4530
# 宏易
# 4532
# 瑞智
# 4533
# 協易機
# 4534
# 三林
# 4535
# 至興
# 4609
# 唐鋒
# 4702
# 中美實
# 4703
# 金美克能
# 4706
# 大恭
# 4707
# 磐亞
# 4711
# 永純
# 4712
# 南璋
# 4714
# 永捷
# 4716
# 大立
# 4717
# 天泰
# 4720
# 德淵
# 4721
# 美琪瑪
# 4801
# 景泰
# 4903
# 聯光通信
# 4904
# 遠傳
# 4905
# 台聯電訊
# 4906
# 正文
# 4907
# 正華
# 4908
# 前鼎
# 4909
# 新復興
# 4910
# 陽慶
# 5006
# 高鋁
# 5007
# 三星
# 5009
# 榮剛
# 5011
# 久陽
# 5013
# 強新
# 5014
# 建錩實業
# 5015
# 華祺工業
# 5016
# 松和
# 5017
# 新泰伸
# 5102
# 富強
# 5201
# 凱衛資訊
# 5202
# 力新
# 5203
# 訊連
# ...
